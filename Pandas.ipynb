# %%
import pandas as pd
v2=pd.read_csv("cleaning_sample.csv")
print(v2)
# Out:
#     Unnamed: 0     Duration  Date  Pulse  MaxP  Calories
# 0           60  2022/12/01'   110    125  10.1       NaN
# 1           60  2022/12/01'   111    126  11.1       NaN
# 2           60  2022/12/01'   112    187  12.1       NaN
# 3           60  2022/12/01'    95    158  13.1       NaN
# 4           60  2022/12/01'   100    125  14.1       NaN
# 5           60          NaN   102    123  15.1       NaN
# 6           60  2022/12/01'   100    125  14.1       NaN
# 7           60  2022/12/01'   184    187  17.1       NaN
# 8           60  2022/12/01'   119    125  18.1       NaN
# 9           60  2022/12/01'    58    147  19.1       NaN
# 10          60  2022/12/01'    90    123   NaN       NaN
# 11          60  2022/12/01'    98    156  15.1       NaN
# 12          60  2022/12/01'    93    131  15.3       NaN
# 13          60  2022/12/01'    45    132  14.9       NaN
# 14          60     20221201   104    133  12.3       NaN
# ...

# %%
a=v2["MaxP"].mean()
g=v2["MaxP"].fillna(a)
print(g)
print(v2)
# Out:
# 0     10.100000
# 1     11.100000
# 2     12.100000
# 3     13.100000
# 4     14.100000
# 5     15.100000
# 6     14.100000
# 7     17.100000
# 8     18.100000
# 9     19.100000
# 10    13.727273
# 11    15.100000
# 12    15.300000
# 13    14.900000
# 14    12.300000
# 15    12.700000
# 16    12.300000
# 17    14.900000
# 18    12.800000
# 19    12.800000
# 20    12.800000
# 21    12.000000
# 22    10.100000
# Name: MaxP, dtype: float64
#     Unnamed: 0     Duration  Date  Pulse  MaxP  Calories
# 0           60  2022/12/01'   110    125  10.1       NaN
# 1           60  2022/12/01'   111    126  11.1       NaN
# 2           60  2022/12/01'   112    187  12.1       NaN
# 3           60  2022/12/01'    95    158  13.1       NaN
# 4           60  2022/12/01'   100    125  14.1       NaN
# 5           60          NaN   102    123  15.1       NaN
# 6           60  2022/12/01'   100    125  14.1       NaN
# 7           60  2022/12/01'   184    187  17.1       NaN
# ...

# %%
import pandas as pd
v2=pd.read_csv("cleaning_sample.csv")
print(v2)
# Out:
#     Unnamed: 0     Duration  Date  Pulse  MaxP  Calories
# 0           60  2022/12/01'   110    125  10.1       NaN
# 1           60  2022/12/01'   111    126  11.1       NaN
# 2           60  2022/12/01'   112    187  12.1       NaN
# 3           60  2022/12/01'    95    158  13.1       NaN
# 4           60  2022/12/01'   100    125  14.1       NaN
# 5           60          NaN   102    123  15.1       NaN
# 6           60  2022/12/01'   100    125  14.1       NaN
# 7           60  2022/12/01'   184    187  17.1       NaN
# 8           60  2022/12/01'   119    125  18.1       NaN
# 9           60  2022/12/01'    58    147  19.1       NaN
# 10          60  2022/12/01'    90    123   NaN       NaN
# 11          60  2022/12/01'    98    156  15.1       NaN
# 12          60  2022/12/01'    93    131  15.3       NaN
# 13          60  2022/12/01'    45    132  14.9       NaN
# 14          60     20221201   104    133  12.3       NaN
# ...

# %%
v2['Duration']=pd.to_datetime(v2['Duration'])
v2
# Out:
#     Unnamed: 0   Duration  Date  Pulse  MaxP  Calories
# 0           60 2022-12-01   110    125  10.1       NaN
# 1           60 2022-12-01   111    126  11.1       NaN
# 2           60 2022-12-01   112    187  12.1       NaN
# 3           60 2022-12-01    95    158  13.1       NaN
# 4           60 2022-12-01   100    125  14.1       NaN
# 5           60        NaT   102    123  15.1       NaN
# 6           60 2022-12-01   100    125  14.1       NaN
# 7           60 2022-12-01   184    187  17.1       NaN
# 8           60 2022-12-01   119    125  18.1       NaN
# 9           60 2022-12-01    58    147  19.1       NaN
# 10          60 2022-12-01    90    123   NaN       NaN
# 11          60 2022-12-01    98    156  15.1       NaN
# 12          60 2022-12-01    93    131  15.3       NaN
# 13          60 2022-12-01    45    132  14.9       NaN
# 14          60 2022-12-01   104    133  12.3       NaN
# 15          60 2022-12-01   115    134  12.7       NaN
# ...

# %%
v2.dropna(subset=['Duration'])
v2
# Out:
#     Unnamed: 0   Duration  Date  Pulse  MaxP  Calories
# 0           60 2022-12-01   110    125  10.1       NaN
# 1           60 2022-12-01   111    126  11.1       NaN
# 2           60 2022-12-01   112    187  12.1       NaN
# 3           60 2022-12-01    95    158  13.1       NaN
# 4           60 2022-12-01   100    125  14.1       NaN
# 5           60        NaT   102    123  15.1       NaN
# 6           60 2022-12-01   100    125  14.1       NaN
# 7           60 2022-12-01   184    187  17.1       NaN
# 8           60 2022-12-01   119    125  18.1       NaN
# 9           60 2022-12-01    58    147  19.1       NaN
# 10          60 2022-12-01    90    123   NaN       NaN
# 11          60 2022-12-01    98    156  15.1       NaN
# 12          60 2022-12-01    93    131  15.3       NaN
# 13          60 2022-12-01    45    132  14.9       NaN
# 14          60 2022-12-01   104    133  12.3       NaN
# 15          60 2022-12-01   115    134  12.7       NaN
# ...

# %%
v2=pd.read_csv("cleaning_sample.csv")
print(v2)
# Out:
#     Unnamed: 0     Duration  Date  Pulse  MaxP  Calories
# 0           60  2022/12/01'   110    125  10.1       NaN
# 1           60  2022/12/01'   111    126  11.1       NaN
# 2           60  2022/12/01'   112    187  12.1       NaN
# 3           60  2022/12/01'    95    158  13.1       NaN
# 4           60  2022/12/01'   100    125  14.1       NaN
# 5           60          NaN   102    123  15.1       NaN
# 6           60  2022/12/01'   100    125  14.1       NaN
# 7           60  2022/12/01'   184    187  17.1       NaN
# 8           60  2022/12/01'   119    125  18.1       NaN
# 9           60  2022/12/01'    58    147  19.1       NaN
# 10          60  2022/12/01'    90    123   NaN       NaN
# 11          60  2022/12/01'    98    156  15.1       NaN
# 12          60  2022/12/01'    93    131  15.3       NaN
# 13          60  2022/12/01'    45    132  14.9       NaN
# 14          60     20221201   104    133  12.3       NaN
# ...

# %%
v3=v2.dropna(subset=['Duration'])
v3
# Out:
#     Unnamed: 0     Duration  Date  Pulse  MaxP  Calories
# 0           60  2022/12/01'   110    125  10.1       NaN
# 1           60  2022/12/01'   111    126  11.1       NaN
# 2           60  2022/12/01'   112    187  12.1       NaN
# 3           60  2022/12/01'    95    158  13.1       NaN
# 4           60  2022/12/01'   100    125  14.1       NaN
# 6           60  2022/12/01'   100    125  14.1       NaN
# 7           60  2022/12/01'   184    187  17.1       NaN
# 8           60  2022/12/01'   119    125  18.1       NaN
# 9           60  2022/12/01'    58    147  19.1       NaN
# 10          60  2022/12/01'    90    123   NaN       NaN
# 11          60  2022/12/01'    98    156  15.1       NaN
# 12          60  2022/12/01'    93    131  15.3       NaN
# 13          60  2022/12/01'    45    132  14.9       NaN
# 14          60     20221201   104    133  12.3       NaN
# 15          60  2022/12/01'   115    134  12.7       NaN
# ...

# %%
v2.loc[10,'MaxP']=20.1
v2
# Out:
#     Unnamed: 0     Duration  Date  Pulse  MaxP  Calories
# 0           60  2022/12/01'   110    125  10.1       NaN
# 1           60  2022/12/01'   111    126  11.1       NaN
# 2           60  2022/12/01'   112    187  12.1       NaN
# 3           60  2022/12/01'    95    158  13.1       NaN
# 4           60  2022/12/01'   100    125  14.1       NaN
# 5           60          NaN   102    123  15.1       NaN
# 6           60  2022/12/01'   100    125  14.1       NaN
# 7           60  2022/12/01'   184    187  17.1       NaN
# 8           60  2022/12/01'   119    125  18.1       NaN
# 9           60  2022/12/01'    58    147  19.1       NaN
# 10          60  2022/12/01'    90    123  20.1       NaN
# 11          60  2022/12/01'    98    156  15.1       NaN
# 12          60  2022/12/01'    93    131  15.3       NaN
# 13          60  2022/12/01'    45    132  14.9       NaN
# 14          60     20221201   104    133  12.3       NaN
# ...

# %%
print(v2.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# dtype: bool

# %%
v2.drop_duplicates()
v2
# Out:
#     Unnamed: 0     Duration  Date  Pulse  MaxP  Calories
# 0           60  2022/12/01'   110    125  10.1       NaN
# 1           60  2022/12/01'   111    126  11.1       NaN
# 2           60  2022/12/01'   112    187  12.1       NaN
# 3           60  2022/12/01'    95    158  13.1       NaN
# 4           60  2022/12/01'   100    125  14.1       NaN
# 5           60          NaN   102    123  15.1       NaN
# 7           60  2022/12/01'   184    187  17.1       NaN
# 8           60  2022/12/01'   119    125  18.1       NaN
# 9           60  2022/12/01'    58    147  19.1       NaN
# 10          60  2022/12/01'    90    123  20.1       NaN
# 11          60  2022/12/01'    98    156  15.1       NaN
# 12          60  2022/12/01'    93    131  15.3       NaN
# 13          60  2022/12/01'    45    132  14.9       NaN
# 14          60     20221201   104    133  12.3       NaN
# 15          60  2022/12/01'   115    134  12.7       NaN
# ...

# %%
v2.corr()
# Out:
#             Unnamed: 0      Date     Pulse      MaxP  Calories
# Unnamed: 0    1.000000  0.136877 -0.052843  0.080287       NaN
# Date          0.136877  1.000000  0.339008  0.027450       NaN
# Pulse        -0.052843  0.339008  1.000000  0.032247       NaN
# MaxP          0.080287  0.027450  0.032247  1.000000       NaN
# Calories           NaN       NaN       NaN       NaN       NaN

# %%
import matplotlib.pyplot as plt
v3=pd.read_csv("cleaning_sample.csv")
v3.plot()
plt.show()

# %%
v3.plot(kind='hist',x='Date',y='Pulse')
plt.show()

# %%
v4=v3["MaxP"].plot(kind='hist')
v4
